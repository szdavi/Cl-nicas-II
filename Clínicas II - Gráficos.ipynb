# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
TRF4 = pd.read_excel("GRÁFICOS.xlsx")

# %%
TRF4
# Out:
#            EXPRESSÃO-CHAVE    CLASSE                 NÚMERO CNJ
# 0   CRIME(S) ELEITORAL(IS)       ACR  5017440-59.2016.4.04.7001
# 1   CRIME(S) ELEITORAL(IS)        HC  5043772-80.2017.4.04.0000
# 2   CRIME(S) ELEITORAL(IS)       RSE  5022953-65.2017.4.04.7100
# 3         CÓDIGO ELEITORAL        AC  5058556-73.2015.4.04.7100
# 4         CÓDIGO ELEITORAL        AC  5008849-81.2016.4.04.7204
# 5         CÓDIGO ELEITORAL        AC  5007942-40.2015.4.04.7205
# 6         CÓDIGO ELEITORAL        AC  5063239-56.2015.4.04.7100
# 7         CÓDIGO ELEITORAL        AC  5058559-28.2015.4.04.7100
# 8         CÓDIGO ELEITORAL        AC  5005145-85.2015.4.04.7110
# 9         CÓDIGO ELEITORAL        HC  5043772-80.2017.4.04.0000
# 10        CÓDIGO ELEITORAL        AC  5058556-73.2015.4.04.7100
# 11        CÓDIGO ELEITORAL        AC  5005753-83.2015.4.04.7110
# 12        CÓDIGO ELEITORAL       RSE  5022953-65.2017.4.04.7100
# 13        CÓDIGO ELEITORAL        AC  5004862-62.2015.4.04.7110
# ...

# %%
EXPRESSÕES = sns.countplot(data = TRF4.sort_values("EXPRESSÃO-CHAVE"), y = "EXPRESSÃO-CHAVE")
EXPRESSÕES.set_xlabel("QUANTIDADE")
# Out:
# Text(0.5, 0, 'QUANTIDADE')

# %%
TRF1 = pd.read_excel("GRÁFICOS.xlsx")

# %%
TRF1
# Out:
#            EXPRESSÃO-CHAVE CLASSE                 NÚMERO CNJ
# 0   CRIME(S) ELEITORAL(IS)     HC  1030701-29.2018.4.01.0000
# 1   CRIME(S) ELEITORAL(IS)     AC  0008559-90.2015.4.01.3900
# 2   CRIME(S) ELEITORAL(IS)    ACR  0005609-79.2012.4.01.3200
# 3   CRIME(S) ELEITORAL(IS)     AC  0000575-70.2015.4.01.3604
# 4   CRIME(S) ELEITORAL(IS)     AC  0000937-61.2013.4.01.3501
# 5   CRIME(S) ELEITORAL(IS)     AC  0006566-30.2014.4.01.3000
# 6   CRIME(S) ELEITORAL(IS)    AMS  0001026-31.2012.4.01.3821
# 7   CRIME(S) ELEITORAL(IS)     HC  0059890-11.2014.4.01.0000
# 8         CÓDIGO ELEITORAL     AC  0028102-02.2016.4.01.3300
# 9         CÓDIGO ELEITORAL     HC  1030701-29.2018.4.01.0000
# 10        CÓDIGO ELEITORAL     AC  0006856-43.2013.4.01.3400
# 11        CÓDIGO ELEITORAL     AC  0008559-90.2015.4.01.3900
# 12        CÓDIGO ELEITORAL    ACR  0001815-09.2010.4.01.3301
# 13        CÓDIGO ELEITORAL     AC  0030166-67.2012.4.01.3900
# ...

# %%
EXPRESSÕES = sns.countplot(data = TRF1.sort_values("EXPRESSÃO-CHAVE"), y = "EXPRESSÃO-CHAVE")
EXPRESSÕES.set_xlabel("QUANTIDADE")
# Out:
# Text(0.5, 0, 'QUANTIDADE')

# %%
STJ = pd.read_excel("GRÁFICOS.xlsx")

# %%
STJ
# Out:
#    CLASSE                 NÚMERO CNJ                     RELATOR ÓRGÃO ORIGEM  \
# 0     APN  0193629-47.2021.3.00.0000      JOÃO OTÁVIO DE NORONHA     TRE - GO
# 1   ARESP  0029175-19.2013.8.07.0000  REYNALDO SOARES DA FONSECA     TJ - DFT
# 2   ARESP  5041287-88.2019.4.04.7000                 LAURITA VAZ      TRF - 4
# 3   ARESP  5021606-29.2020.4.02.5101             JESUÍNO RISSATO      TRF - 2
# 4   ARESP  5014913-35.2019.4.04.7000   ANTONIO SALDANHA PALHEIRO      TRF - 4
# 5      HC  0251682-21.2021.3.00.0000   ANTONIO SALDANHA PALHEIRO      TRF - 4
# 6    RESP  5051606-23.2016.4.04.7000            DANIELA TEIXEIRA      TRF - 4
# 7    RESP  5029994-29.2016.4.04.7000      JOÃO OTÁVIO DE NORONHA      TRF - 4
# 8    RESP  5018749-16.2019.4.04.7000   ANTONIO SALDANHA PALHEIRO      TRF - 4
# 9    RESP  5054932-88.2016.4.04.7000             JESUÍNO RISSATO      TRF - 4
# 10   RESP  5008581-52.2019.4.04.7000   ANTONIO SALDANHA PALHEIRO      TRF - 4
# ...

# %%
CLASSE = sns.countplot(data = STJ.sort_values("CLASSE"), y = "CLASSE")
CLASSE.set_xlabel("QUANTIDADE")
# Out:
# Text(0.5, 0, 'QUANTIDADE')

# %%
CLASSE = sns.countplot(data = STJ.sort_values("RELATOR"), y = "RELATOR")
CLASSE.set_xlabel("QUANTIDADE")
# Out:
# Text(0.5, 0, 'QUANTIDADE')

# %%
STJ["DURAÇÃO"].describe()
# Out:
# count      17.000000
# mean      543.176471
# std       285.657407
# min       133.000000
# 25%       313.000000
# 50%       588.000000
# 75%       618.000000
# max      1407.000000
# Name: DURAÇÃO, dtype: float64

# %%
FASE_ATUAL = sns.countplot(data = STJ.sort_values("FASE ATUAL"), y = "FASE ATUAL")
FASE_ATUAL.set_xlabel("QUANTIDADE")
# Out:
# Text(0.5, 0, 'QUANTIDADE')

# %%
ÓRGÃO_ATUAL = sns.countplot(data = STJ.sort_values("ÓRGÃO ATUAL"), y = "ÓRGÃO ATUAL")
ÓRGÃO_ATUAL.set_xlabel("QUANTIDADE")
# Out:
# Text(0.5, 0, 'QUANTIDADE')

# %%
REL_ANTONIO = STJ[STJ["RELATOR"] == "ANTONIO SALDANHA PALHEIRO"]

# %%
REL_ANTONIO["DURAÇÃO"].describe()
# Out:
# count     10.000000
# mean     516.400000
# std      185.833976
# min      133.000000
# 25%      428.750000
# 50%      581.500000
# 75%      615.000000
# max      770.000000
# Name: DURAÇÃO, dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

FINAL = pd.read_excel("GRÁFICOS.xlsx")
FINAL
# Out:
#            EXPRESSÃO-CHAVE CLASSE                 NÚMERO CNJ DESCARTADO  \
# 0                      NaN   APEL  0600013-53.2021.6.16.0003        NÃO
# 1                      NaN   APEL  0600045-95.2020.6.16.0002        NÃO
# 2                      NaN   APEL  0600080-43.2022.6.16.0145        NÃO
# 3                      NaN   APEL  0600144-31.2021.6.16.0002        NÃO
# 4   CRIME(S) ELEITORAL(IS)    ACR  5017440-59.2016.4.04.7001        SIM
# 5   CRIME(S) ELEITORAL(IS)     HC  5043772-80.2017.4.04.0000        SIM
# 6   CRIME(S) ELEITORAL(IS)    RSE  5022953-65.2017.4.04.7100        SIM
# 7         CÓDIGO ELEITORAL     HC  5043772-80.2017.4.04.0000        SIM
# 8         CÓDIGO ELEITORAL    RSE  5022953-65.2017.4.04.7100        SIM
# 9         CÓDIGO ELEITORAL     HC  5043493-31.2016.4.04.0000        SIM
# 10                     NaN    RSE  0600017-69.2022.6.27.0029        NÃO
# 11                     NaN    RSE  0600085-53.2021.6.27.0029        NÃO
# ...

# %%
TRE_PR = FINAL[FINAL["PRIMEIRA INSTÂNCIA"] == "002ª ZE DE CURITIBA PR"]
TRE_PR
# Out:
#   EXPRESSÃO-CHAVE CLASSE                 NÚMERO CNJ DESCARTADO  \
# 0             NaN   APEL  0600013-53.2021.6.16.0003        NÃO
# 1             NaN   APEL  0600045-95.2020.6.16.0002        NÃO
# 2             NaN   APEL  0600080-43.2022.6.16.0145        NÃO
# 3             NaN   APEL  0600144-31.2021.6.16.0002        NÃO
#
#        PRIMEIRA INSTÂNCIA                          JUIZ(A)  \
# 0  002ª ZE DE CURITIBA PR  MYCHELLE PACHECO CINTRA STADLER
# 1  002ª ZE DE CURITIBA PR  MYCHELLE PACHECO CINTRA STADLER
# 2  002ª ZE DE CURITIBA PR  MYCHELLE PACHECO CINTRA STADLER
# 3  002ª ZE DE CURITIBA PR  MYCHELLE PACHECO CINTRA STADLER
#
#           DATA INICIAL DATA FINAL     FASE ATUAL SEGUNDA INSTÂNCIA RELATOR(A)  \
# 0  2021-02-26 00:00:00        NaT  EM TRAMITAÇÃO               NaN        NaN
# 1  2020-07-31 00:00:00        NaT  EM TRAMITAÇÃO               NaN        NaN
# 2  2022-12-05 00:00:00 2024-05-14      ARQUIVADO               NaN        NaN
# ...

# %%
FASE_ATUAL = sns.countplot(data = TRE_PR.sort_values("FASE ATUAL"), y = "FASE ATUAL")
FASE_ATUAL.set_xlabel("")
# Out:
# Text(0.5, 0, '')

# %%
TRE_TO = FINAL[FINAL["PRIMEIRA INSTÂNCIA"] == "029ª ZE DE PALMAS TO"]
TRE_TO
# Out:
#    EXPRESSÃO-CHAVE CLASSE                 NÚMERO CNJ DESCARTADO  \
# 10             NaN    RSE  0600017-69.2022.6.27.0029        NÃO
# 11             NaN    RSE  0600085-53.2021.6.27.0029        NÃO
# 12             NaN    RSE  0600129-72.2021.6.27.0029        NÃO
# 13             NaN    RSE  0601425-66.2020.6.27.0029        NÃO
# 14             NaN    RSE  0600094-15.2021.6.27.0029        NÃO
# 15             NaN    RSE  0600092-45.2021.6.27.0029        NÃO
# 16             NaN    RSE  0600116-73.2021.6.27.0029        NÃO
# 17             NaN    RSE  0600004-07.2021.6.27.0029        NÃO
# 18             NaN    RSE  0600087-23.2021.6.27.0029        NÃO
# 19             NaN    RSE  0600119-28.2021.6.27.0029        NÃO
# 20             NaN    RSE  0600086-38.2021.6.27.0029        NÃO
# 21             NaN    RSE  0600127-05.2021.6.27.0029        NÃO
#
#       PRIMEIRA INSTÂNCIA                                    JUIZ(A)  \
# ...

# %%
RELATOR = sns.countplot(data = TRE_TO.sort_values("JUIZ(A)"), y = "JUIZ(A)")
RELATOR.set_xlabel("QUANTIDADE")
# Out:
# Text(0.5, 0, 'QUANTIDADE')

# %%
FASE_ATUAL = sns.countplot(data = TRE_TO.sort_values("FASE ATUAL"), y = "FASE ATUAL")
FASE_ATUAL.set_xlabel("")
# Out:
# Text(0.5, 0, '')

# %%
FASE_ATUAL = sns.countplot(data = TRE_TO.sort_values("ASSUNTO"), y = "ASSUNTO")
FASE_ATUAL.set_xlabel("QUANTIDADE")
# Out:
# Text(0.5, 0, 'QUANTIDADE')

# %%
TRF = FINAL[(FINAL["SEGUNDA INSTÂNCIA"] == "TRF-4") | (FINAL["SEGUNDA INSTÂNCIA"] == "TRF-1")]
TRF
# Out:
#            EXPRESSÃO-CHAVE CLASSE                 NÚMERO CNJ DESCARTADO  \
# 4   CRIME(S) ELEITORAL(IS)    ACR  5017440-59.2016.4.04.7001        SIM
# 5   CRIME(S) ELEITORAL(IS)     HC  5043772-80.2017.4.04.0000        SIM
# 6   CRIME(S) ELEITORAL(IS)    RSE  5022953-65.2017.4.04.7100        SIM
# 7         CÓDIGO ELEITORAL     HC  5043772-80.2017.4.04.0000        SIM
# 8         CÓDIGO ELEITORAL    RSE  5022953-65.2017.4.04.7100        SIM
# 9         CÓDIGO ELEITORAL     HC  5043493-31.2016.4.04.0000        SIM
# 22  CRIME(S) ELEITORAL(IS)     HC  1030701-29.2018.4.01.0000        SIM
# 23  CRIME(S) ELEITORAL(IS)    ACR  0005609-79.2012.4.01.3200        SIM
# 24  CRIME(S) ELEITORAL(IS)     HC  0059890-11.2014.4.01.0000        SIM
# 25        CÓDIGO ELEITORAL     HC  1030701-29.2018.4.01.0000        SIM
# 26        CÓDIGO ELEITORAL    ACR  0001815-09.2010.4.01.3301        SIM
# 27        CÓDIGO ELEITORAL   PIMP  0031502-98.2014.4.01.0000        SIM
# ...

# %%
TRF_4 = TRF = FINAL[FINAL["SEGUNDA INSTÂNCIA"] == "TRF-4"]
TRF_4
# Out:
#           EXPRESSÃO-CHAVE CLASSE                 NÚMERO CNJ DESCARTADO  \
# 4  CRIME(S) ELEITORAL(IS)    ACR  5017440-59.2016.4.04.7001        SIM
# 5  CRIME(S) ELEITORAL(IS)     HC  5043772-80.2017.4.04.0000        SIM
# 6  CRIME(S) ELEITORAL(IS)    RSE  5022953-65.2017.4.04.7100        SIM
# 7        CÓDIGO ELEITORAL     HC  5043772-80.2017.4.04.0000        SIM
# 8        CÓDIGO ELEITORAL    RSE  5022953-65.2017.4.04.7100        SIM
# 9        CÓDIGO ELEITORAL     HC  5043493-31.2016.4.04.0000        SIM
#
#           PRIMEIRA INSTÂNCIA                         JUIZ(A)  \
# 4       5ª VF DE LONDRINA PR      RICHARD RODRIGUES AMBROSIO
# 5                        NaN                             NaN
# 6  22ª VF DE PORTO ALEGRE RS  CRISTINA DE ALBUQUERQUE VIEIRA
# 7                        NaN                             NaN
# 8  22ª VF DE PORTO ALEGRE RS  CRISTINA DE ALBUQUERQUE VIEIRA
# 9                        NaN                             NaN
#
# ...

# %%
TRF_1 = TRF = FINAL[FINAL["SEGUNDA INSTÂNCIA"] == "TRF-1"]
TRF_1
# Out:
#            EXPRESSÃO-CHAVE CLASSE                 NÚMERO CNJ DESCARTADO  \
# 22  CRIME(S) ELEITORAL(IS)     HC  1030701-29.2018.4.01.0000        SIM
# 23  CRIME(S) ELEITORAL(IS)    ACR  0005609-79.2012.4.01.3200        SIM
# 24  CRIME(S) ELEITORAL(IS)     HC  0059890-11.2014.4.01.0000        SIM
# 25        CÓDIGO ELEITORAL     HC  1030701-29.2018.4.01.0000        SIM
# 26        CÓDIGO ELEITORAL    ACR  0001815-09.2010.4.01.3301        SIM
# 27        CÓDIGO ELEITORAL   PIMP  0031502-98.2014.4.01.0000        SIM
# 28         COMPRA DE VOTOS    ACR  0005609-79.2012.4.01.3200        SIM
# 29         COMPRA DE VOTOS     HC  0059890-11.2014.4.01.0000        SIM
# 30    PROPAGANDA ELEITORAL     HC  0027550-43.2016.4.01.0000        SIM
#
#                    PRIMEIRA INSTÂNCIA                              JUIZ(A)  \
# 22                                NaN                                  NaN
# 23                     4ª VARA MANAUS  ANA PAULA SERIZAWA SILVA PODEDWORNY
# ...

# %%
FINAL = pd.read_excel("GRÁFICOS.xlsx")
FINAL
# Out:
#    CLASSE                 NÚMERO CNJ DESCARTADO      PRIMEIRA INSTÂNCIA  \
# 0    APEL  0600013-53.2021.6.16.0003        NÃO  002ª ZE DE CURITIBA PR
# 1    APEL  0600045-95.2020.6.16.0002        NÃO  002ª ZE DE CURITIBA PR
# 2    APEL  0600080-43.2022.6.16.0145        NÃO  002ª ZE DE CURITIBA PR
# 3    APEL  0600144-31.2021.6.16.0002        NÃO  002ª ZE DE CURITIBA PR
# 4     RSE  0600017-69.2022.6.27.0029        NÃO    029ª ZE DE PALMAS TO
# 5     RSE  0600085-53.2021.6.27.0029        NÃO    029ª ZE DE PALMAS TO
# 6     RSE  0600129-72.2021.6.27.0029        NÃO    029ª ZE DE PALMAS TO
# 7     RSE  0601425-66.2020.6.27.0029        NÃO    029ª ZE DE PALMAS TO
# 8     RSE  0600094-15.2021.6.27.0029        NÃO    029ª ZE DE PALMAS TO
# 9     RSE  0600092-45.2021.6.27.0029        NÃO    029ª ZE DE PALMAS TO
# 10    RSE  0600116-73.2021.6.27.0029        NÃO    029ª ZE DE PALMAS TO
# 11    RSE  0600004-07.2021.6.27.0029        NÃO    029ª ZE DE PALMAS TO
# ...

# %%
TRE_PR = FINAL[FINAL["PRIMEIRA INSTÂNCIA"] == "002ª ZE DE CURITIBA PR"]
TRE_PR
# Out:
#   CLASSE                 NÚMERO CNJ DESCARTADO      PRIMEIRA INSTÂNCIA  \
# 0   APEL  0600013-53.2021.6.16.0003        NÃO  002ª ZE DE CURITIBA PR
# 1   APEL  0600045-95.2020.6.16.0002        NÃO  002ª ZE DE CURITIBA PR
# 2   APEL  0600080-43.2022.6.16.0145        NÃO  002ª ZE DE CURITIBA PR
# 3   APEL  0600144-31.2021.6.16.0002        NÃO  002ª ZE DE CURITIBA PR
#
#                            JUIZ(A)         DATA INICIAL DATA FINAL  DURAÇÃO  \
# 0  MYCHELLE PACHECO CINTRA STADLER  2021-02-26 00:00:00 2024-06-05     1195
# 1  MYCHELLE PACHECO CINTRA STADLER  2020-07-31 00:00:00 2024-06-05     1405
# 2  MYCHELLE PACHECO CINTRA STADLER  2022-12-05 00:00:00 2024-05-14     1256
# 3  MYCHELLE PACHECO CINTRA STADLER  2021-10-21 00:00:00 2024-06-05      958
#
#       FASE ATUAL  SEGUNDA INSTÂNCIA  RELATOR(A)  DATA INICIAL.1  DATA FINAL.1  \
# 0  EM TRAMITAÇÃO                NaN         NaN             NaN           NaN
# ...

# %%
TRE_PR["DURAÇÃO"].describe()
# Out:
# count       4.000000
# mean     1203.500000
# std       185.922027
# min       958.000000
# 25%      1135.750000
# 50%      1225.500000
# 75%      1293.250000
# max      1405.000000
# Name: DURAÇÃO, dtype: float64

# %%
TRE_TO = FINAL[FINAL["PRIMEIRA INSTÂNCIA"] == "029ª ZE DE PALMAS TO"]
TRE_TO
# Out:
#    CLASSE                 NÚMERO CNJ DESCARTADO    PRIMEIRA INSTÂNCIA  \
# 4     RSE  0600017-69.2022.6.27.0029        NÃO  029ª ZE DE PALMAS TO
# 5     RSE  0600085-53.2021.6.27.0029        NÃO  029ª ZE DE PALMAS TO
# 6     RSE  0600129-72.2021.6.27.0029        NÃO  029ª ZE DE PALMAS TO
# 7     RSE  0601425-66.2020.6.27.0029        NÃO  029ª ZE DE PALMAS TO
# 8     RSE  0600094-15.2021.6.27.0029        NÃO  029ª ZE DE PALMAS TO
# 9     RSE  0600092-45.2021.6.27.0029        NÃO  029ª ZE DE PALMAS TO
# 10    RSE  0600116-73.2021.6.27.0029        NÃO  029ª ZE DE PALMAS TO
# 11    RSE  0600004-07.2021.6.27.0029        NÃO  029ª ZE DE PALMAS TO
# 12    RSE  0600087-23.2021.6.27.0029        NÃO  029ª ZE DE PALMAS TO
# 13    RSE  0600119-28.2021.6.27.0029        NÃO  029ª ZE DE PALMAS TO
# 14    RSE  0600086-38.2021.6.27.0029        NÃO  029ª ZE DE PALMAS TO
# 15    RSE  0600127-05.2021.6.27.0029        NÃO  029ª ZE DE PALMAS TO
#
# ...

# %%
TRE_TO["DURAÇÃO"].describe()
# Out:
# count      12.000000
# mean     1044.166667
# std       141.125240
# min       732.000000
# 25%       975.500000
# 50%      1052.500000
# 75%      1095.000000
# max      1269.000000
# Name: DURAÇÃO, dtype: float64

# %%
FINAL["DURAÇÃO"].describe()
# Out:
# count      16.00000
# mean     1084.00000
# std       163.08321
# min       732.00000
# 25%       975.50000
# 50%      1055.50000
# 75%      1199.75000
# max      1405.00000
# Name: DURAÇÃO, dtype: float64
