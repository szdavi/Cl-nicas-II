# %%
# !pip install openai
# !pip install tqdm

# %%
import os

# Lista de textos para serem processados
path = 'C:/Users/davif/Downloads/Clínicas II'
textos = list()
for arquivo in os.listdir(path):
    if arquivo.endswith('.txt'):
        with open(os.path.join(path, arquivo), "r", encoding="utf8") as f:
            texto = f.read()
            textos.append(texto)

textos
# Out:
# [' \n\n\n\nJUSTIÇA ELEITORAL\nTRIBUNAL REGIONAL ELEITORAL DO TOCANTINS\n \nRECURSO CRIMINAL ELEITORAL (14209) - Processo nº 0600017-69.2022.6.27.0029 - Palmas - TOCANTINS\n\nASSUNTO: RECURSO EM SENTIDO ESTRITO\n\nRECORRENTE: MARCELO DE CARVALHO MIRANDA, SERGIO LEAO\n\nADVOGADOS: JAIR ALVES PEREIRA - OAB/RS 46872 e MARLA CRISTINA LIMA SOUSA - OAB/TO 5749\n\nRECORRIDO: MINISTÉRIO PUBLICO ELEITORAL\n\nRELATOR: Juiz(a) ANA PAULA BRANDAO BRASIL\n\n \n\n \n\nD E C I S Ã O.\n\n \n\n \n\nTratam-se de recursos em sentido estrito interpostos por MARCELO DE CARVALHO MIRANDA e SÉRGIO LEÃO contra decisão de ID 9803105, proferida pelo juízo da 29ª Zona Eleitoral do Tocantins que conheceu dos embargos de declaração e lhes negou provimento, determinando, por consequência o imediato cumprimento da sentença  que determinou o desmembramento e remessa dos autos à 4ª Vara Federal Criminal da Seção Judiciária do Estado do Tocantins, para processamento dos crimes tipificados artigo 312, caput, c/c artigo 3
# ...

# %%
from openai import OpenAI
import os
from tqdm import tqdm
import json

client = OpenAI(api_key="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")

# Lista de textos para serem processados
path = 'C:/Users/davif/Downloads/Clínicas II'
textos = list()
for arquivo in os.listdir(path):
    if arquivo.endswith('.txt'):
        with open(os.path.join(path, arquivo), "r", encoding="utf8") as f:
            texto = f.read()
            textos.append(texto)

# Perguntas a serem feitas ao modelo
perguntas = """
Quem é o(a) relator(a) do processo?
Qual(is) é(são) o(s) crime(s) que está(ão) sendo imputado(s) ao réu(s)?
Qual foi a decisão da primeira instância?
Qual foi a decisão da segunda instância?
"""

# Lista para armazenar os dados extraídos
dados_extraidos = []

# Itere sobre cada texto na lista de textos
for texto in tqdm(textos):
    texto_entrada = texto[:30000]
    response = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": f"Você é um assistente jurídico e vai responder a perguntas sobre processos na Justiça Eleitoral. Use o texto a seguir como base para suas respostas: {texto_entrada}. Responda as perguntas em um JSON e mantenha a pergunta original."},
            {"role": "user", "content": perguntas},
        ]
    )
    dados_extraidos.append(response.choices[0].message['content'])

# Exibir os dados extraídos
for dado in dados_extraidos:
    print(dado)
# Out:
#   0%|                                                                                            | 0/1 [00:08<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 38
#      30     texto_entrada = texto[:30000]
#      31     response = client.chat.completions.create(
#      32         model="gpt-4o",
#      33         messages=[
#    (...)
#      36         ]
#      37     )
# ---> 38     dados_extraidos.append(response.choices[0].message['content'])
#      40 # Exibir os dados extraídos
#      41 for dado in dados_extraidos:
#
# TypeError: 'ChatCompletionMessage' object is not subscriptable

# %%
from openai import OpenAI

import os

from tqdm import tqdm

import json

 

client = OpenAI(api_key="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")

 

# Lista de textos para serem processados

path = 'C:/Users/davif/Downloads/Clínicas II'

textos = list()

for arquivo in os.listdir(path):

    if arquivo.endswith('.txt'):

        with open(os.path.join(path, arquivo), "r", encoding="utf8") as f:

            texto = f.read()

            textos.append(texto)

 

# Perguntas a serem feitas ao modelo

perguntas = """

Quem é o(a) relator(a) do processo?

Qual(is) é(são) o(s) crime(s) que está(ão) sendo imputado(s) ao réu(s)?

Qual foi a decisão da primeira instância?

Qual foi a decisão da segunda instância?

"""

 

# Lista para armazenar os dados extraídos

dados_extraidos = []

 

# Itere sobre cada texto na lista de textos

for texto in tqdm(textos):

    texto_entrada = texto[:30000]

    response = client.chat.completions.create(

        model="gpt-4o",

        messages=[

            {"role": "system", "content": f"Você é um assistente jurídico e vai responder a perguntas sobre processos na vara da juventude. Use o texto a seguir como base para suas respostas: {texto_entrada}. Responda as perguntas em um JSON e mantenha a pergunta original."},

            {"role": "user", "content": perguntas},

        ]

    )

    dados_extraidos.append(response.choices[0].message['content'])

 

# Exibir os dados extraídos

for dado in dados_extraidos:

    print(dado)
# Out:
#   0%|                                                                                            | 0/1 [00:12<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 75
#      59     texto_entrada = texto[:30000]
#      61     response = client.chat.completions.create(
#      62
#      63         model="gpt-4o",
#    (...)
#      72
#      73     )
# ---> 75     dados_extraidos.append(response.choices[0].message['content'])
#      79 # Exibir os dados extraídos
#      81 for dado in dados_extraidos:
#
# TypeError: 'ChatCompletionMessage' object is not subscriptable
